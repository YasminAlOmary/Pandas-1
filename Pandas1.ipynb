# %% [markdown]
# ## Panadas 1

# %%
import pandas as pd

# %%
file_path =('C:/Users/user/class-dic.csv')

# %%
df1=pd.read_csv(file_path )

# %%
# To change table (CSV) file to dict 
class_dict=df1.to_dict()

# %%
class_dict
# Out:
# {'name': {0: 'Ali',
#   1: 'Yasmin',
#   2: 'etibar',
#   3: 'mohammd',
#   4: 'ahmad ',
#   5: 'dawn',
#   6: 'zahra',
#   7: 'hussein ',
#   8: 'fatima ',
#   9: 'munia',
#   10: 'khadra',
#   11: 'yaser',
#   12: 'ibrahim'},
#  'gender': {0: 'm',
#   1: 'f',
#   2: 'f',
#   3: 'm',
#   4: 'm',
#   5: 'f',
#   6: 'f',
#   7: 'm',
#   8: 'f',
#   9: 'f',
#   10: 'f',
#   11: 'm',
#   12: 'm'},
#  'age ': {0: 35,
#   1: 31,
#   2: 55,
#   3: 58,
#   4: 51,
#   5: 35,
#   6: 2,
#   7: 83,
#   8: 80,
#   9: 31,
#   10: 70,
#   11: 45,
#   12: 75},
#  'math_score': {0: 90,
#   1: 90,
#   2: 80,
#   3: 80,
#   4: 70,
#   5: 87,
#   6: 65,
#   7: 85,
#   8: 70,
#   9: 80,
#   10: 91,
#   11: 77,
#   12: 66},
#  'study_ hour': {0: 12,
#   1: 14,
#   2: 10,
#   3: 9,
#   4: 5,
#   5: 11,
#   6: 9,
#   7: 8,
#   8: 7,
#   9: 6,
#   10: 12,
#   11: 9,
#   12: 8},
#  'work': {0: 'full time',
#   1: 'part time',
#   2: 'part time',
#   3: 'full time',
#   4: 'part time',
#   5: 'full time',
# ...

# %%
## To change dict to DataFrame

# %%
df=pd.DataFrame(class_dict)

# %%
df
# Out:
#         name gender  age   math_score  study_ hour       work
# 0        Ali      m    35          90           12  full time
# 1     Yasmin      f    31          90           14  part time
# 2     etibar      f    55          80           10  part time
# 3    mohammd      m    58          80            9  full time
# 4     ahmad       m    51          70            5  part time
# 5       dawn      f    35          87           11  full time
# 6      zahra      f     2          65            9  part time
# 7   hussein       m    83          85            8  full time
# 8    fatima       f    80          70            7  part time
# 9      munia      f    31          80            6  full time
# 10    khadra      f    70          91           12  part time
# 11     yaser      m    45          77            9  full time
# 12   ibrahim      m    75          66            8  full time

# %%
type (df)
# Out:
# pandas.core.frame.DataFrame

# %%
#  To appear the data header by default for 5 rows
df.head ()
# Out:
#       name gender  age   math_score  study_ hour       work
# 0      Ali      m    35          90           12  full time
# 1   Yasmin      f    31          90           14  part time
# 2   etibar      f    55          80           10  part time
# 3  mohammd      m    58          80            9  full time
# 4   ahmad       m    51          70            5  part time

# %%
df.head (3)
# Out:
#      name gender  age   math_score  study_ hour       work
# 0     Ali      m    35          90           12  full time
# 1  Yasmin      f    31          90           14  part time
# 2  etibar      f    55          80           10  part time

# %%
#  To appear the data tail by default for 5 rows
df.tail ()
# Out:
#        name gender  age   math_score  study_ hour       work
# 8   fatima       f    80          70            7  part time
# 9     munia      f    31          80            6  full time
# 10   khadra      f    70          91           12  part time
# 11    yaser      m    45          77            9  full time
# 12  ibrahim      m    75          66            8  full time

# %%
# to find the numerical information about table such as count , mean, std,etc. 
#For numerical data –columns sucah as age ,score ,,,etc.

df.describe()
# Out:
#             age   math_score  study_ hour
# count  13.000000   13.000000    13.000000
# mean   50.076923   79.307692     9.230769
# std    23.460824    9.213980     2.554533
# min     2.000000   65.000000     5.000000
# 25%    35.000000   70.000000     8.000000
# 50%    51.000000   80.000000     9.000000
# 75%    70.000000   87.000000    11.000000
# max    83.000000   91.000000    14.000000

# %%
df
# Out:
#         name gender  age   math_score  study_ hour       work
# 0        Ali      m    35          90           12  full time
# 1     Yasmin      f    31          90           14  part time
# 2     etibar      f    55          80           10  part time
# 3    mohammd      m    58          80            9  full time
# 4     ahmad       m    51          70            5  part time
# 5       dawn      f    35          87           11  full time
# 6      zahra      f     2          65            9  part time
# 7   hussein       m    83          85            8  full time
# 8    fatima       f    80          70            7  part time
# 9      munia      f    31          80            6  full time
# 10    khadra      f    70          91           12  part time
# 11     yaser      m    45          77            9  full time
# 12   ibrahim      m    75          66            8  full time

# %%
# df.info()to find Non-Null Count data 
#string in dataframe called "object "
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 0 to 12
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         13 non-null     object
#  1   gender       13 non-null     object
#  2   age          13 non-null     int64
#  3   math_score   13 non-null     int64
#  4   study_ hour  13 non-null     int64
#  5   work         13 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 728.0+ bytes

# %%
a='Smith '
type (a)
# Out:
# str

# %%
class_dict
# Out:
# {'name': {0: 'Ali',
#   1: 'Yasmin',
#   2: 'etibar',
#   3: 'mohammd',
#   4: 'ahmad ',
#   5: 'dawn',
#   6: 'zahra',
#   7: 'hussein ',
#   8: 'fatima ',
#   9: 'munia',
#   10: 'khadra',
#   11: 'yaser',
#   12: 'ibrahim'},
#  'gender': {0: 'm',
#   1: 'f',
#   2: 'f',
#   3: 'm',
#   4: 'm',
#   5: 'f',
#   6: 'f',
#   7: 'm',
#   8: 'f',
#   9: 'f',
#   10: 'f',
#   11: 'm',
#   12: 'm'},
#  'age ': {0: 35,
#   1: 31,
#   2: 55,
#   3: 58,
#   4: 51,
#   5: 35,
#   6: 2,
#   7: 83,
#   8: 80,
#   9: 31,
#   10: 70,
#   11: 45,
#   12: 75},
#  'math_score': {0: 90,
#   1: 90,
#   2: 80,
#   3: 80,
#   4: 70,
#   5: 87,
#   6: 65,
#   7: 85,
#   8: 70,
#   9: 80,
#   10: 91,
#   11: 77,
#   12: 66},
#  'study_ hour': {0: 12,
#   1: 14,
#   2: 10,
#   3: 9,
#   4: 5,
#   5: 11,
#   6: 9,
#   7: 8,
#   8: 7,
#   9: 6,
#   10: 12,
#   11: 9,
#   12: 8},
#  'work': {0: 'full time',
#   1: 'part time',
#   2: 'part time',
#   3: 'full time',
#   4: 'part time',
#   5: 'full time',
# ...

# %%
df
# Out:
#         name gender  age   math_score  study_ hour       work
# 0        Ali      m    35          90           12  full time
# 1     Yasmin      f    31          90           14  part time
# 2     etibar      f    55          80           10  part time
# 3    mohammd      m    58          80            9  full time
# 4     ahmad       m    51          70            5  part time
# 5       dawn      f    35          87           11  full time
# 6      zahra      f     2          65            9  part time
# 7   hussein       m    83          85            8  full time
# 8    fatima       f    80          70            7  part time
# 9      munia      f    31          80            6  full time
# 10    khadra      f    70          91           12  part time
# 11     yaser      m    45          77            9  full time
# 12   ibrahim      m    75          66            8  full time

# %%
 # df.dtypes :to appear all column name and data type (int ,object ,float) .
df.dtypes
# Out:
# name           object
# gender         object
# age             int64
# math_score      int64
# study_ hour     int64
# work           object
# dtype: object

# %%
# df['name'] or  df.names :  to appear the first column from dataframe .
df['name']
# Out:
# 0          Ali
# 1       Yasmin
# 2       etibar
# 3      mohammd
# 4       ahmad
# 5         dawn
# 6        zahra
# 7     hussein
# 8      fatima
# 9        munia
# 10      khadra
# 11       yaser
# 12     ibrahim
# Name: name, dtype: object

# %%
df.name
# Out:
# 0          Ali
# 1       Yasmin
# 2       etibar
# 3      mohammd
# 4       ahmad
# 5         dawn
# 6        zahra
# 7     hussein
# 8      fatima
# 9        munia
# 10      khadra
# 11       yaser
# 12     ibrahim
# Name: name, dtype: object

# %%
df
# Out:
#         name gender  age   math_score  study_ hour       work
# 0        Ali      m    35          90           12  full time
# 1     Yasmin      f    31          90           14  part time
# 2     etibar      f    55          80           10  part time
# 3    mohammd      m    58          80            9  full time
# 4     ahmad       m    51          70            5  part time
# 5       dawn      f    35          87           11  full time
# 6      zahra      f     2          65            9  part time
# 7   hussein       m    83          85            8  full time
# 8    fatima       f    80          70            7  part time
# 9      munia      f    31          80            6  full time
# 10    khadra      f    70          91           12  part time
# 11     yaser      m    45          77            9  full time
# 12   ibrahim      m    75          66            8  full time

# %%
df['study_ hour']
# Out:
# 0     12
# 1     14
# 2     10
# 3      9
# 4      5
# 5     11
# 6      9
# 7      8
# 8      7
# 9      6
# 10    12
# 11     9
# 12     8
# Name: study_ hour, dtype: int64

# %%
study =df['study_ hour']
study
# Out:
# 0     12
# 1     14
# 2     10
# 3      9
# 4      5
# 5     11
# 6      9
# 7      8
# 8      7
# 9      6
# 10    12
# 11     9
# 12     8
# Name: study_ hour, dtype: int64

# %%
print (study.max())
print (study.min())
print (study.mean())
# Out:
# 14
# 5
# 9.23076923076923

# %%
# df.columns :to appear all column name of dataframe    
df.columns
# Out:
# Index(['name', 'gender', 'age ', 'math_score', 'study_ hour', 'work'], dtype='object')

# %%
 columns= df.columns

# %%
columns
# Out:
# Index(['name', 'gender', 'age ', 'math_score', 'study_ hour', 'work'], dtype='object')

# %%
#df[columns[1]] :to appear the data of column that indexed 1 
df[columns[1]]
# Out:
# 0     m
# 1     f
# 2     f
# 3     m
# 4     m
# 5     f
# 6     f
# 7     m
# 8     f
# 9     f
# 10    f
# 11    m
# 12    m
# Name: gender, dtype: object

# %%
df[columns[3]]
# Out:
# 0     90
# 1     90
# 2     80
# 3     80
# 4     70
# 5     87
# 6     65
# 7     85
# 8     70
# 9     80
# 10    91
# 11    77
# 12    66
# Name: math_score, dtype: int64

# %%
#df.loc[:,:]  : to appear location all dataset –data frame and no condition between square bracket
df.loc[:,:]
# Out:
#         name gender  age   math_score  study_ hour       work
# 0        Ali      m    35          90           12  full time
# 1     Yasmin      f    31          90           14  part time
# 2     etibar      f    55          80           10  part time
# 3    mohammd      m    58          80            9  full time
# 4     ahmad       m    51          70            5  part time
# 5       dawn      f    35          87           11  full time
# 6      zahra      f     2          65            9  part time
# 7   hussein       m    83          85            8  full time
# 8    fatima       f    80          70            7  part time
# 9      munia      f    31          80            6  full time
# 10    khadra      f    70          91           12  part time
# 11     yaser      m    45          77            9  full time
# 12   ibrahim      m    75          66            8  full time

# %%
# to appear the data of name munia with all columns 
df.loc[df['name']== 'munia',: ]
# Out:
#     name gender  age   math_score  study_ hour       work
# 9  munia      f    31          80            6  full time

# %%
# to appear the specific  data
df.loc[df ['name']== 'munia' ,  ['name' ,'math_score','gender']]
# Out:
#     name  math_score gender
# 9  munia          80      f

# %%
df.loc[0:4,   ['name' ,'math_score','gender'] ]
# Out:
#       name  math_score gender
# 0      Ali          90      m
# 1   Yasmin          90      f
# 2   etibar          80      f
# 3  mohammd          80      m
# 4   ahmad           70      m

# %%
#location
df.iloc[0:4,0:4 ]
# Out:
#       name gender  age   math_score
# 0      Ali      m    35          90
# 1   Yasmin      f    31          90
# 2   etibar      f    55          80
# 3  mohammd      m    58          80

# %%
#index
df.iloc[0:4,0:5]
# Out:
#       name gender  age   math_score  study_ hour
# 0      Ali      m    35          90           12
# 1   Yasmin      f    31          90           14
# 2   etibar      f    55          80           10
# 3  mohammd      m    58          80            9

# %%
df.loc[df ['gender']== 'm',:]
# Out:
#         name gender  age   math_score  study_ hour       work
# 0        Ali      m    35          90           12  full time
# 3    mohammd      m    58          80            9  full time
# 4     ahmad       m    51          70            5  part time
# 7   hussein       m    83          85            8  full time
# 11     yaser      m    45          77            9  full time
# 12   ibrahim      m    75          66            8  full time

# %%
df.loc[df ['gender']== 'f',:]
# Out:
#        name gender  age   math_score  study_ hour       work
# 1    Yasmin      f    31          90           14  part time
# 2    etibar      f    55          80           10  part time
# 5      dawn      f    35          87           11  full time
# 6     zahra      f     2          65            9  part time
# 8   fatima       f    80          70            7  part time
# 9     munia      f    31          80            6  full time
# 10   khadra      f    70          91           12  part time

# %%
df.loc[df ['gender']== 'f',['name' ,'math_score','gender']]
# Out:
#        name  math_score gender
# 1    Yasmin          90      f
# 2    etibar          80      f
# 5      dawn          87      f
# 6     zahra          65      f
# 8   fatima           70      f
# 9     munia          80      f
# 10   khadra          91      f

# %%
df.loc[df['math_score']> 80,:]
# Out:
#         name gender  age   math_score  study_ hour       work
# 0        Ali      m    35          90           12  full time
# 1     Yasmin      f    31          90           14  part time
# 5       dawn      f    35          87           11  full time
# 7   hussein       m    83          85            8  full time
# 10    khadra      f    70          91           12  part time

# %%
df.loc[df['math_score']< 80,:]
# Out:
#        name gender  age   math_score  study_ hour       work
# 4    ahmad       m    51          70            5  part time
# 6     zahra      f     2          65            9  part time
# 8   fatima       f    80          70            7  part time
# 11    yaser      m    45          77            9  full time
# 12  ibrahim      m    75          66            8  full time

# %%
df.loc[df['math_score']> 80,['name' ,'math_score','gender']]
# Out:
#         name  math_score gender
# 0        Ali          90      m
# 1     Yasmin          90      f
# 5       dawn          87      f
# 7   hussein           85      m
# 10    khadra          91      f

# %%
df.loc[df['math_score']<80,['name' ,'math_score','gender']]
# Out:
#        name  math_score gender
# 4    ahmad           70      m
# 6     zahra          65      f
# 8   fatima           70      f
# 11    yaser          77      m
# 12  ibrahim          66      m
